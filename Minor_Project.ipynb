# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejas240699/Mini-Project/blob/main/Minor_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bing-image-downloader
# Out:
# Collecting bing-image-downloader
#   Downloading https://files.pythonhosted.org/packages/0d/bf/537a61030b84ae4cd5022d5c7b014fd9bc3ce7c02358919153a6658a61d3/bing_image_downloader-1.0.4-py3-none-any.whl
# Installing collected packages: bing-image-downloader
# Successfully installed bing-image-downloader-1.0.4

# %%
import bing_image_downloader

# %%
# !mkdir images

# %%
from bing_image_downloader import downloader
downloader.download('animals', limit=15,  output_dir='images', adult_filter_off=True, force_replace=False, timeout=60)
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 15 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.pbs.org/wnet/nature/files/2014/10/AnimalsBehavingBadly-Main.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://www.pixelstalk.net/wp-content/uploads/2016/03/Animals-cubs-Africa-lions-baby-wallpaper-1920x1080.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://wallup.net/wp-content/uploads/2016/01/214547-nature-animals-wildlife-lion.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://cdn.images.express.co.uk/img/dynamic/128/590x/africa-animals-677711.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://media.npr.org/assets/img/2019/09/16/wildhood_wide-86ce299d635fc579b0f4f710c00ff54b382d37d6.jpg?s=1400
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://cdn.givingcompass.org/wp-content/uploads/2018/08/30102030/How-We-Protect-Endangered-Animals.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #7 from https://www.fodors.com/wp-content/uploads/2017/08/Australian-Animals-Koala.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #8 from https://news.nationalgeographic.com/content/dam/news/2016/02/24/01highanimals.ngsversion.1456244998811.adapt.1900.1.jpg
# [!] Issue getting: https://news.nationalgeographic.com/content/dam/news/2016/02/24/01highanimals.ngsversion.1456244998811.adapt.1900.1.jpg
# [!] Error:: The read operation timed out
# [%] Downloading Image #8 from https://keyassets.timeincuk.net/inspirewp/live/wp-content/uploads/sites/8/2019/06/MAMMG3-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #9 from https://static3.therichestimages.com/wordpress/wp-content/uploads/2017/01/super-predators-animals.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #10 from https://www.catersnews.com/wp-content/uploads/2014/11/1_CATERS_HYBRID_ANIMALS_27.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #11 from https://media2.s-nbcnews.com/i/streams/2013/October/131030/8C9539467-philadelphiazoo-snowleopardcub.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #12 from http://1.bp.blogspot.com/--eihkZozZAE/VIH80ibcCdI/AAAAAAABPXY/rxxFFZbuy24/w1200-h630-p-k-no-nu/funny-animals-13701.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #13 from http://justsomething.co/wp-content/uploads/2014/05/animals-hangover.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #14 from http://dreamicus.com/data/animals/animals-04.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #15 from https://www.pbs.org/wnet/nature/files/2014/10/AnimalsBehavingBadly-Main.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 15 images.
#
# ===============================================

# %%
from bing_image_downloader import downloader
downloader.download('birds', limit=15,  output_dir='images', adult_filter_off=True, force_replace=False, timeout=60)
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 15 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from http://highlighthollywood.com/wp-content/uploads/2018/10/birds-drunk-minnesota.jpg
# [!] Issue getting: http://highlighthollywood.com/wp-content/uploads/2018/10/birds-drunk-minnesota.jpg
# [!] Error:: <urlopen error [Errno 110] Connection timed out>
# [%] Downloading Image #1 from http://entertainmentmesh.com/wp-content/uploads/2017/02/cute-parrot-birds.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.readersdigest.ca/wp-content/uploads/2018/05/types-of-birds-in-canada-stellers-jay.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.lovethegarden.com/sites/default/files/content/articles/UK_wildbirds-01-robin.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://tonsoffacts.com/wp-content/uploads/2017/12/hummingbird-bird-birds-349758.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://weneedfun.com/wp-content/uploads/2016/06/exotic-birds-16.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://wallup.net/wp-content/uploads/2016/01/4265-parrot-birds-animals.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #7 from http://www.wallpapers13.com/wp-content/uploads/2016/02/Beautiful_Multicolor_Parrot_Exotic-birds_Wallpaper-Hd-1920x1440.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #8 from https://pixfeeds.com/images/birds/parrots/1280-1200-500908705-female-eclectus-parrot.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #9 from http://weneedfun.com/wp-content/uploads/2016/06/colorful-birds-flying-18.jpg
# [Error]Invalid image, not saving http://weneedfun.com/wp-content/uploads/2016/06/colorful-birds-flying-18.jpg
#
# [!] Issue getting: http://weneedfun.com/wp-content/uploads/2016/06/colorful-birds-flying-18.jpg
# [!] Error:: No active exception to reraise
# [%] Downloading Image #9 from https://peterlachnewinsky.files.wordpress.com/2011/10/australian-birds.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #10 from https://media.buzzle.com/media/images-en/gallery/birds/budgie/1200-178785139-green-budgie.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #11 from https://wallpaperrasim.files.wordpress.com/2014/05/blue-macaw-parrot-birds-wallpapers.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #12 from https://pixfeeds.com/images/birds/parrots/640-1200-157374129-scarlet-macaws.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #13 from http://media.fromthegrapevine.com/assets/images/2015/9/blue-birds.jpg.824x0_q71.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #14 from http://highlighthollywood.com/wp-content/uploads/2018/10/birds-drunk-minnesota.jpg
# [!] Issue getting: http://highlighthollywood.com/wp-content/uploads/2018/10/birds-drunk-minnesota.jpg
# [!] Error:: <urlopen error [Errno 110] Connection timed out>
# [%] Downloading Image #14 from http://entertainmentmesh.com/wp-content/uploads/2017/02/cute-parrot-birds.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #15 from https://www.lovethegarden.com/sites/default/files/content/articles/UK_wildbirds-01-robin.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 15 images.
#
# ===============================================

# %%
from bing_image_downloader import downloader
downloader.download('plants', limit=15,  output_dir='images', adult_filter_off=True, force_replace=False, timeout=60)
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 15 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://assets.heart.co.uk/2018/14/house-plants-3-1523446012.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://jenbosen.com/wp-content/uploads/2016/03/snake-plant-healthy-leaves.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://plantworks.com/wp-content/gallery/artificial-tropical-plants/a13882.jpg
# [!] Issue getting: https://plantworks.com/wp-content/gallery/artificial-tropical-plants/a13882.jpg
# [!] Error:: HTTP Error 404: Not Found
# [%] Downloading Image #3 from http://www.miamitropicalplants.com/wp-content/uploads/2016/09/Luseane-Bonsai.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://spaceoptimized.com/wp-content/uploads/2017/06/space-optimized-tiny-apartment-house-plants.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://samlovesadventure.files.wordpress.com/2013/06/succulent.png
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://worldoffloweringplants.com/wp-content/uploads/2014/10/Aloe-aristata-Torch-Plant2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #7 from http://www.wearefound.com/wp-content/uploads/2017/01/vegetable-garden-celery-plants.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #8 from https://q7i2y6d5.stackpathcdn.com/wp-content/uploads/2016/12/zone-4-yucca.jpg
# [!] Issue getting: https://q7i2y6d5.stackpathcdn.com/wp-content/uploads/2016/12/zone-4-yucca.jpg
# [!] Error:: hostname 'www.q7i2y6d5.stackpathcdn.com' doesn't match either of '*.ssl.hwcdn.net', 'ssl.hwcdn.net'
# [%] Downloading Image #8 from https://cdn.arstechnica.net/wp-content/uploads/2018/05/JamesPetts_Flickr_Plants-800x600.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #9 from https://cdn.vox-cdn.com/thumbor/-NX6pVWkwBAIkJleDE62qMh_76E=/1000x0/cdn.vox-cdn.com/uploads/chorus_asset/file/16385600/71ruPaTWy7L._SL1500_.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #10 from https://tierraplants.com/wp-content/uploads/2017/05/final-philodendron.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #11 from https://www.sargentsnursery.com/wp-content/uploads/2015/02/indoor-plants-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #12 from https://healingspiritplants.files.wordpress.com/2010/05/hsp2010roger532.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #13 from http://allthingsplants.com/pics/2014-03-16/Toni/41119e.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #14 from https://plantworks.com/wp-content/gallery/artificial-tropical-plants/a13882.jpg
# [!] Issue getting: https://plantworks.com/wp-content/gallery/artificial-tropical-plants/a13882.jpg
# [!] Error:: HTTP Error 404: Not Found
# [%] Downloading Image #14 from http://www.wearefound.com/wp-content/uploads/2017/01/vegetable-garden-celery-plants.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #15 from https://q7i2y6d5.stackpathcdn.com/wp-content/uploads/2016/12/zone-4-yucca.jpg
# [!] Issue getting: https://q7i2y6d5.stackpathcdn.com/wp-content/uploads/2016/12/zone-4-yucca.jpg
# [!] Error:: hostname 'www.q7i2y6d5.stackpathcdn.com' doesn't match either of '*.ssl.hwcdn.net', 'ssl.hwcdn.net'
# [%] Downloading Image #15 from https://img.thrfun.com/img/151/689/what_is_eating_my_pepper_plants_leaves_l9.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 15 images.
#
# ===============================================

# %%
import numpy as np
from skimage.transform import resize
from skimage.io import imread
import matplotlib.pyplot as plt
import os

target = []
images = []
flat_data = []

DATADIR = '/content/images'
CATEGORIES = ['animals','birds','plants']

for category in CATEGORIES:
  class_num = CATEGORIES.index(category)
  path = os.path.join(DATADIR,category)
  for img in os.listdir(path):
    img_array = imread(os.path.join(path,img))
    img_resized = resize(img_array,(150,150,3))
    flat_data.append(img_resized.flatten())
    images.append(img_resized)
    target.append(class_num)

target = np.array(target)
images = np.array(images)
flat_data = np.array(flat_data)

# %%
import pandas as pd
df = pd.DataFrame(flat_data)
df['Target'] = target
df
# Out:
#            0         1         2  ...     67498     67499  Target
# 0   0.250235  0.400000  0.144745  ...  0.000000  0.000000       0
# 1   0.538000  0.391804  0.149373  ...  0.038863  0.023529       0
# 2   0.115686  0.441503  0.798039  ...  0.296078  0.166340       0
# 3   0.111627  0.198176  0.119608  ...  0.600000  0.600000       0
# 4   0.170758  0.172549  0.129412  ...  0.196078  0.146889       0
# 5   0.486275  0.788235  0.941176  ...  0.839216  0.866667       0
# 6   0.027451  0.047059  0.065763  ...  0.330065  0.356863       0
# 7   0.780392  0.780392  0.792157  ...  0.756863  0.800000       0
# 8   0.250235  0.400000  0.144745  ...  0.000000  0.000000       0
# 9   0.232549  0.221569  0.205882  ...  0.603529  0.564314       0
# 10  0.611765  0.682353  0.760784  ...  0.553196  0.562314       0
# 11  0.276209  0.219608  0.078431  ...  0.176471  0.043137       0
# 12  0.416732  0.334379  0.237037  ...  0.770980  0.643137       0
# 13  0.964706  0.940196  0.876471  ...  0.946078  0.945098       0
# 14  0.996078  0.996078  0.996078  ...  0.996078  0.996078       0
# 15  0.615686  0.560784  0.525490  ...  0.092105  0.043633       1
# 16  0.909804  0.945098  0.972549  ...  0.827451  0.854902       1
# 17  0.768510  0.333333  0.113725  ...  0.537255  0.011373       1
# 18  0.431373  0.568627  0.000000  ...  0.737255  0.435294       1
# 19  0.294118  0.321569  0.286144  ...  0.301961  0.078431       1
# 20  0.435294  0.425490  0.454902  ...  0.317647  0.337255       1
# 21  0.109412  0.074314  0.003922  ...  0.498039  0.596078       1
# 22  0.796078  0.858824  0.815686  ...  0.094118  0.058824       1
# 23  0.796078  0.858824  0.815686  ...  0.094118  0.058824       1
# 24  0.000000  0.019608  0.000000  ...  0.027451  0.000000       1
# 25  0.295176  0.294118  0.266667  ...  0.545098  0.545098       1
# 26  0.615686  0.560784  0.525490  ...  0.092105  0.043633       1
# 27  0.250980  0.352941  0.298039  ...  0.905882  0.925490       1
# 28  0.384314  0.317647  0.286275  ...  0.121569  0.125490       1
# 29  0.149020  0.313725  0.305882  ...  0.709843  0.553333       1
# 30  0.043137  0.043137  0.025490  ...  0.047059  0.027451       2
# 31  0.752941  0.749020  0.764706  ...  0.750327  0.262200       2
# 32  0.196275  0.301638  0.145294  ...  0.220484  0.302820       2
# 33  0.663399  0.694771  0.702614  ...  0.659440  0.638993       2
# 34  0.560784  0.490850  0.052211  ...  0.101961  0.000000       2
# 35  0.788235  0.788235  0.788235  ...  0.841176  0.829412       2
# 36  0.660131  0.694771  0.730065  ...  0.337908  0.353595       2
# 37  0.196275  0.301638  0.145294  ...  0.220484  0.302820       2
# 38  0.996078  0.996078  0.996078  ...  0.996078  0.996078       2
# 39  0.874510  0.921569  0.898039  ...  0.545098  0.362778       2
# 40  0.619477  0.693987  0.431373  ...  0.510065  0.144967       2
# 41  0.262364  0.348538  0.189139  ...  0.107765  0.092078       2
# 42  0.035294  0.078105  0.058824  ...  0.242484  0.051961       2
# 43  1.000000  1.000000  1.000000  ...  0.557516  0.505882       2
# 44  0.996078  0.996078  0.996078  ...  0.996078  0.996078       2
#
# [45 rows x 67501 columns]

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor

dataset = datasets.load_diabetes()
X = dataset.data; y = dataset.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

GBR = GradientBoostingRegressor()

parameters = {'learning_rate': [0.01,0.02,0.03,0.04],
                  'subsample'    : [0.9, 0.5, 0.2, 0.1],
                  'n_estimators' : [100,500,1000, 1500],
                  'max_depth'    : [4,6,8,10]
                 }
grid_GBR = GridSearchCV(estimator=GBR, param_grid = parameters, cv = 2, n_jobs=-1)
grid_GBR.fit(X_train, y_train)

print(" Results from Grid Search " )
print("\n The best estimator across ALL searched params:\n",grid_GBR.best_estimator_)
print("\n The best score across ALL searched params:\n",grid_GBR.best_score_)
print("\n The best parameters across ALL searched params:\n",grid_GBR.best_params_)
# Out:
#  Results from Grid Search
#
#  The best estimator across ALL searched params:
#  GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.02, loss='ls', max_depth=8,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=500,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=None, subsample=0.1, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)
#
#  The best score across ALL searched params:
#  0.43378344271471425
#
#  The best parameters across ALL searched params:
#  {'learning_rate': 0.02, 'max_depth': 8, 'n_estimators': 500, 'subsample': 0.1}

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

actual = [1,0,0,1,0,0,1,0,0,1]

predicted = [1,0,0,1,0,0,0,1,0,0]

matrix = confusion_matrix(actual,predicted, labels=[1,0])
print('Confusion matrix : \n',matrix)

tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
print('Outcome values : \n', tp, fn, fp, tn)

matrix = classification_report(actual,predicted,labels=[1,0])
print('Classification report : \n',matrix)
# Out:
# Confusion matrix :
#  [[2 2]
#  [1 5]]
# Outcome values :
#  2 2 1 5
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.67      0.50      0.57         4
#            0       0.71      0.83      0.77         6
#
#     accuracy                           0.70        10
#    macro avg       0.69      0.67      0.67        10
# weighted avg       0.70      0.70      0.69        10

# %%
import numpy as np
from sklearn import datasets
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

dataset = datasets.load_diabetes()

alphas = np.array([1,0.1,0.01,0.001,0.0001,0])

model = Ridge()
grid = GridSearchCV(estimator=model, param_grid=dict(alpha=alphas))
grid.fit(dataset.data, dataset.target)
print(grid)

print(grid.best_score_)
print(grid.best_estimator_.alpha)
# Out:
# 0.4823231384163485
# 0.0001

# %%
import logging
from time import time

from numpy.random import RandomState
import matplotlib.pyplot as plt

from sklearn.datasets import fetch_olivetti_faces
from sklearn.cluster import MiniBatchKMeans
from sklearn import decomposition

logging.basicConfig(level=logging.INFO,
                    format='%(asctime)s %(levelname)s %(message)s')
n_row, n_col = 2, 3
n_components = n_row * n_col
image_shape = (64, 64)
rng = RandomState(0)

faces, _ = fetch_olivetti_faces(return_X_y=True, shuffle=True,
                                random_state=rng)
n_samples, n_features = faces.shape

faces_centered = faces - faces.mean(axis=0)

faces_centered -= faces_centered.mean(axis=1).reshape(n_samples, -1)

print("Dataset consists of %d faces" % n_samples)


def plot_gallery(title, images, n_col=n_col, n_row=n_row, cmap=plt.cm.gray):
    plt.figure(figsize=(2. * n_col, 2.26 * n_row))
    plt.suptitle(title, size=16)
    for i, comp in enumerate(images):
        plt.subplot(n_row, n_col, i + 1)
        vmax = max(comp.max(), -comp.min())
        plt.imshow(comp.reshape(image_shape), cmap=cmap,
                   interpolation='nearest',
                   vmin=-vmax, vmax=vmax)
        plt.xticks(())
        plt.yticks(())
    plt.subplots_adjust(0.01, 0.05, 0.99, 0.93, 0.04, 0.)

estimators = [
    ('Eigenfaces - PCA using randomized SVD',
     decomposition.PCA(n_components=n_components, svd_solver='randomized',
                       whiten=True),
     True),

    ('Non-negative components - NMF',
     decomposition.NMF(n_components=n_components, init='nndsvda', tol=5e-3),
     False),

    ('Independent components - FastICA',
     decomposition.FastICA(n_components=n_components, whiten=True),
     True),

    ('Sparse comp. - MiniBatchSparsePCA',
     decomposition.MiniBatchSparsePCA(n_components=n_components, alpha=0.8,
                                      n_iter=100, batch_size=3,
                                      random_state=rng),
     True),

    ('MiniBatchDictionaryLearning',
        decomposition.MiniBatchDictionaryLearning(n_components=15, alpha=0.1,
                                                  n_iter=50, batch_size=3,
                                                  random_state=rng),
     True),

    ('Cluster centers - MiniBatchKMeans',
        MiniBatchKMeans(n_clusters=n_components, tol=1e-3, batch_size=20,
                        max_iter=50, random_state=rng),
     True),

    ('Factor Analysis components - FA',
     decomposition.FactorAnalysis(n_components=n_components, max_iter=20),
     True),
]

plot_gallery("First centered Olivetti faces", faces_centered[:n_components])


for name, estimator, center in estimators:
    print("Extracting the top %d %s..." % (n_components, name))
    t0 = time()
    data = faces
    if center:
        data = faces_centered
    estimator.fit(data)
    train_time = (time() - t0)
    print("done in %0.3fs" % train_time)
    if hasattr(estimator, 'cluster_centers_'):
        components_ = estimator.cluster_centers_
    else:
        components_ = estimator.components_

    if (hasattr(estimator, 'noise_variance_') and
            estimator.noise_variance_.ndim > 0): 
        plot_gallery("Pixelwise variance",
                     estimator.noise_variance_.reshape(1, -1), n_col=1,
                     n_row=1)
    plot_gallery('%s - Train time %.1fs' % (name, train_time),
                 components_[:n_components])

plt.show()


estimators = [
    ('Dictionary learning',
        decomposition.MiniBatchDictionaryLearning(n_components=15, alpha=0.1,
                                                  n_iter=50, batch_size=3,
                                                  random_state=rng),
     True),
    ('Dictionary learning - positive dictionary',
        decomposition.MiniBatchDictionaryLearning(n_components=15, alpha=0.1,
                                                  n_iter=50, batch_size=3,
                                                  random_state=rng,
                                                  positive_dict=True),
     True),
    ('Dictionary learning - positive code',
        decomposition.MiniBatchDictionaryLearning(n_components=15, alpha=0.1,
                                                  n_iter=50, batch_size=3,
                                                  fit_algorithm='cd',
                                                  random_state=rng,
                                                  positive_code=True),
     True),
    ('Dictionary learning - positive dictionary & code',
        decomposition.MiniBatchDictionaryLearning(n_components=15, alpha=0.1,
                                                  n_iter=50, batch_size=3,
                                                  fit_algorithm='cd',
                                                  random_state=rng,
                                                  positive_dict=True,
                                                  positive_code=True),
     True),
]


plot_gallery("First centered Olivetti faces", faces_centered[:n_components],
             cmap=plt.cm.RdBu)

for name, estimator, center in estimators:
    print("Extracting the top %d %s..." % (n_components, name))
    t0 = time()
    data = faces
    if center:
        data = faces_centered
    estimator.fit(data)
    train_time = (time() - t0)
    print("done in %0.3fs" % train_time)
    components_ = estimator.components_
    plot_gallery(name, components_[:n_components], cmap=plt.cm.RdBu)

plt.show()
# Out:
# Dataset consists of 400 faces
# Extracting the top 6 Eigenfaces - PCA using randomized SVD...
# done in 0.053s
# Extracting the top 6 Non-negative components - NMF...
# done in 0.414s
# Extracting the top 6 Independent components - FastICA...
# /usr/local/lib/python3.6/dist-packages/sklearn/decomposition/_fastica.py:119: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning)
# done in 0.293s
# Extracting the top 6 Sparse comp. - MiniBatchSparsePCA...
# done in 0.852s
# Extracting the top 6 MiniBatchDictionaryLearning...
# done in 0.746s
# Extracting the top 6 Cluster centers - MiniBatchKMeans...
# done in 0.218s
# Extracting the top 6 Factor Analysis components - FA...
# done in 0.465s
# Extracting the top 6 Dictionary learning...
# done in 0.771s
# Extracting the top 6 Dictionary learning - positive dictionary...
# done in 0.777s
# Extracting the top 6 Dictionary learning - positive code...
# done in 0.241s
# Extracting the top 6 Dictionary learning - positive dictionary & code...
# done in 0.323s
